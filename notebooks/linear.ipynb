# %% [markdown]
# # <u>Modèle linéaire</u>

# %% [markdown]
# L'objectif du code ici présent, est de vérifier si il est possible de créer un modèle linéaire et si une regression linéaire peut-être utile pour classifier les images du dataset "CIFAR-10".
#
# Dans un premier temps, il est important de savoir que la classification d'image va dépendre des composantes principales d'une image :
#
# - Les pixels indiqués en Rouge-Vert-Bleu
# - Des composantes déterminées par réduction de dimension ou par groupement de composantes.

# %% [markdown]
# ### Imports
#
# Nous allons importer notre dataset directement à partir des datasets présents sur keras :

# %%
from tensorflow.keras.datasets import cifar10

# %% [markdown]
# Nous importons également notre librairie custom, que vous pouvez consulter [en cliquant ici](https://github.com/TheoHd/dl-kaggle-dataset-analysis/blob/theo/src/linear.py)

# %%
import src.models.processes.linear as lnr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-161225aaa0f0> in <module>
# ----> 1 import src.models.processes.linear as lnr
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# On charge les données de CIFAR-10 dans des variables d'entrainement et de validation :

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Tentative de classification d'images directement par pixels

# %%
x = x_train.reshape(50000,32*32*3)
y = y_train

# %%
colors = ['gray','rosybrown','darksalmon','bisque','tan','gold','darkkhaki','olivedrab','royalblue','plum']
labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

red_index = 0
green_index = 1
blue_index = 2

# %% [markdown]
# ### Rapport entre le <span style="color:green;">vert</span> et le <span style="color:red;">rouge</span>

# %%
lnr.plot_rgb_comparison(
    x,
    y,
    red_index,
    green_index,
    colors,
    labels,
    title="Rapport de couleur en fonction des classes",
    xlabel="Niveau de rouge (0-255)",
    ylabel="Niveau de vert (0-255)"
)

# %% [markdown]
# ### Rapport entre le <span style="color:blue;">bleu</span> et le <span style="color:red;">rouge</span>

# %%
lnr.plot_rgb_comparison(
    x,
    y,
    red_index,
    blue_index,
    colors,
    labels,
    xlabel="Niveau de rouge (0-255)",
    ylabel="Niveau de bleu (0-255)"
)

# %% [markdown]
# ### Rapport entre le <span style="color:blue;">bleu</span> et le <span style="color:green;">vert</span>

# %%
lnr.plot_rgb_comparison(
    x,
    y,
    green_index,
    blue_index,
    colors,
    labels,
    xlabel="Niveau de vert (0-255)",
    ylabel="Niveau de bleu (0-255)"
)

# %% [markdown]
# Il est difficile à partir du rapport entre les couleurs d'effectuer une séparation linéaire. Les composantes simples telles
# que les couleurs peuvent fonctionner si les images se ressemblent beaucoup. Or dans notre cas nous cherchons à prédire quel est
# le label de notre image sans pour autant qu'elles soient trop semblables comme dans CIFAR-10.
#
# En essayant de distinguer des composantes plus importantes, on pourrait éventuellement effectuer une séparation linéaire des classes.

# %% [markdown]
# ## Classification d'images par PCA

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %% [markdown]
# ### Séparation des données

# %%
x_train_flat = np.array(x_train[:100]).reshape((100,32*32*3))
pca_dims = PCA()
pca_dims.fit(x_train_flat)
cumsum = np.cumsum(pca_dims.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1

pca = PCA(n_components=d)
x_reduced = pca.fit_transform(x_train_flat)
x_recovered = pca.inverse_transform(x_reduced)

# %%
x_recovered_to_plot = x_recovered[:100].reshape((100, 32 * 32 * 3))
y_to_plot = y_train[:100]

lnr.plot_pca(x_recovered_to_plot, y_to_plot, colors, labels)

# %%
lnr.plot_best_case_scenario(colors, labels)

# %% [markdown]
# Ci-dessus un affichage du cas "parfait" qui nous permettrait de faire une séparation linéaire aisément, pour créer
# un modèle linéaire capable de prédire nos différentes classes.

# %% [markdown]
# Est-il possible de créer un modèle linéaire avec Tensorflow ?
# Nous pouvons toujours essayer en créant un modèle linéaire simple de ce type :

# %%
from  src.models.processes import linear

linear.create_and_train_model()
# Out:
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\responses\
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\responses\
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\logs\
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\logs\tensorboard\fit\
# Successfully created the dir : C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\logs\tensorboard\fit\linear_2_20200129-175333\
# C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\logs\linear_2.log
# C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 5.4801 - sparse_categorical_accuracy: 0.1055
# Epoch 00001: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 3s 53us/sample - loss: 5.4663 - sparse_categorical_accuracy: 0.1055 - val_loss: 5.3030 - val_sparse_categorical_accuracy: 0.1096
# Epoch 2/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 5.7416 - sparse_categorical_accuracy: 0.1091
# Epoch 00002: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 5.8125 - sparse_categorical_accuracy: 0.1087 - val_loss: 8.2331 - val_sparse_categorical_accuracy: 0.0992
# Epoch 3/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 10.3785 - sparse_categorical_accuracy: 0.1172
# Epoch 00003: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 10.4014 - sparse_categorical_accuracy: 0.1173 - val_loss: 12.3715 - val_sparse_categorical_accuracy: 0.1387
# Epoch 4/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 8.4527 - sparse_categorical_accuracy: 0.1016
# Epoch 00004: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 8.3178 - sparse_categorical_accuracy: 0.1010 - val_loss: 4.8515 - val_sparse_categorical_accuracy: 0.0918
# Epoch 5/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8518 - sparse_categorical_accuracy: 0.0871
# Epoch 00005: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8518 - sparse_categorical_accuracy: 0.0871 - val_loss: 4.8515 - val_sparse_categorical_accuracy: 0.0855
# Epoch 6/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8516 - sparse_categorical_accuracy: 0.0828
# Epoch 00006: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8517 - sparse_categorical_accuracy: 0.0824 - val_loss: 4.8515 - val_sparse_categorical_accuracy: 0.0855
# Epoch 7/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.9037 - sparse_categorical_accuracy: 0.0840
# Epoch 00007: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.9008 - sparse_categorical_accuracy: 0.0838 - val_loss: 4.8515 - val_sparse_categorical_accuracy: 0.0861
# Epoch 8/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8514 - sparse_categorical_accuracy: 0.0827
# Epoch 00008: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8515 - sparse_categorical_accuracy: 0.0828 - val_loss: 4.8515 - val_sparse_categorical_accuracy: 0.0862
# Epoch 9/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8518 - sparse_categorical_accuracy: 0.0814
# Epoch 00009: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8518 - sparse_categorical_accuracy: 0.0813 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 10/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00010: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 11/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00011: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 12/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00012: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 13/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00013: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 14/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00014: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 15/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00015: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 16/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0802
# Epoch 00016: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 17/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00017: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 18/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00018: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 19/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00019: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 36us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 20/100
#  - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00020: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 37us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 21/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00021: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 22/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00022: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 38us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 23/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00023: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 36us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 24/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00024: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 25/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00025: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 26/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00026: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 27/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00027: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 28/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00028: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 36us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 29/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00029: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 30/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00030: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 31/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0792
# Epoch 00031: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 32/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00032: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 33/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0803
# Epoch 00033: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 34/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00034: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 35/100
#  - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0816
# Epoch 00035: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 36/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00036: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 37/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00037: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 38/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00038: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 39/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00039: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 40/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00040: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 41/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00041: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 42/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00042: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 1s 30us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 43/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00043: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 44/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00044: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 30us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 45/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00045: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 46/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00046: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 47/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00047: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 48/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00048: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 49/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00049: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 50/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00050: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 51/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00051: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 52/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00052: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 53/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00053: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 54/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00054: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 55/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00055: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 56/100
#  - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0786
# Epoch 00056: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 57/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00057: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 58/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00058: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 59/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00059: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 60/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00060: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 61/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00061: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 36us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 62/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00062: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 63/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00063: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 64/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00064: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 65/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00065: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 66/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00066: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 67/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00067: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 68/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0800
# Epoch 00068: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 69/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00069: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 70/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00070: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 71/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0795
# Epoch 00071: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 72/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00072: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 73/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0801
# Epoch 00073: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 74/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00074: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 40us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 75/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0794
# Epoch 00075: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 76/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00076: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 77/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00077: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 78/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00078: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 37us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 79/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00079: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 80/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0803
# Epoch 00080: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 81/100
# 47104/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00081: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 1s 30us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 82/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00082: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 30us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 83/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00083: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 84/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00084: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 85/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0794
# Epoch 00085: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 86/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00086: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 87/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00087: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 88/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0802
# Epoch 00088: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 89/100
#  - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0785
# Epoch 00089: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 90/100
#  - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0803
# Epoch 00090: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 91/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00091: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 92/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0803
# Epoch 00092: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 37us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 93/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00093: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 94/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0797
# Epoch 00094: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 95/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0802
# Epoch 00095: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 31us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 96/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00096: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 97/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0799
# Epoch 00097: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 34us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 98/100
# 48128/50000 [===========================>..] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0796
# Epoch 00098: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 33us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 99/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00099: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 32us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840
# Epoch 100/100
# 49152/50000 [============================>.] - ETA: 0s - loss: 4.8520 - sparse_categorical_accuracy: 0.0798
# Epoch 00100: saving model to C:\Users\thuchard\PycharmProjects\dl-kaggle-dataset-analysis\src\models\checkspoints\linear_2.ckpt
# 50000/50000 [==============================] - 2s 35us/sample - loss: 4.8520 - sparse_categorical_accuracy: 0.0798 - val_loss: 4.8516 - val_sparse_categorical_accuracy: 0.0840

# %% [markdown]
# On observe que notre précision diminue avec au final un `sparse_categorical_accuracy: 0.1055` qui passe à `0.0798` et un
# `val_sparse_categorical_accuracy: 0.1096` qui passe à `val_sparse_categorical_accuracy: 0.0840` ce qui est normal pour
# le type de données que l'on a.

# %% [markdown]
# ## Conclusion
#
# On remarque qu'il n'est pas possible de créer simplement un modèle linéaire à partir de nos données brut. La méthode
# de la régression linéaire n'est donc pas vraiment adaptée à nos images.
#
# Le modèle linéaire est beaucoup plus adapté quand par example on a des données évidentes et comparable avec au moins
# la capacité de tracer une droite de régression pouvant séparer linéairement nos classes. Dans le cas contraire
# il est impossible de prédire correctement les différentes classes de CIFAR-10.
#
# Cependant il existe d'autres méthodes plus adaptées à ce dataset que vous pouvez consulter dans les autres notebooks présent dans ce dossier.
